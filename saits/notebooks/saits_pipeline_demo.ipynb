# %% [markdown]
# # SAITS Pipeline Demo
#
# This notebook is intentionally thin. The realistic MIT training method lives in `saits/src/train.py` and `saits/src/dynamic_train.py`.
# Provide your own data path in `saits/config.example.yaml` before running.

# %%
# Train sensor-only SAITS with realistic block masks as the MIT task.
# !python -m saits.src.train --config saits/config.example.yaml

# %%
# Evaluate the saved SAITS checkpoint.
# !python -m saits.src.evaluate --config saits/config.example.yaml
