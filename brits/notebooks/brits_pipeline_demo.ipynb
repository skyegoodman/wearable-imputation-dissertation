# %% [markdown]
# # BRITS Pipeline Demo
#
# This notebook is intentionally thin. The training method lives in `brits/src/train.py`.
# Provide your own data path in `brits/config.example.yaml` before running.

# %%
# Train BRITS with TOD + circadian harmonic auxiliary channels.
# !python -m brits.src.train --config brits/config.example.yaml

# %%
# Evaluate the saved BRITS checkpoint.
# !python -m brits.src.evaluate --config brits/config.example.yaml
